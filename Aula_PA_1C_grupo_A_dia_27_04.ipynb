# %% [markdown]
# <a href="https://colab.research.google.com/github/mmanuss/PA-1C-grupo-A/blob/main/Aula_PA_1C_grupo_A_dia_27_04.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Interações e laços de repetição

for i in range (5):
   print ("olá mundo!")
# Out:
# olá mundo!
# olá mundo!
# olá mundo!
# olá mundo!
# olá mundo!

# %%
for i in range (5):
   print (i)
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
for i in range (1,6):
   print (i)
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
# escrever um programa que imprime de 5 até 0

for i in range (6):
   print (5- i)
# Out:
# 5
# 4
# 3
# 2
# 1
# 0

# %%
# escrever um programa que imprime os números pares de 0 a 10

for i in range (1):
   print (2,4,6,8,10)
# Out:
# 2 4 6 8 10

# %%
# escrever um programa que imprime os números pares de 0 a 10

for i in range (11):

  if i % 2 == 0:
    print (i)
# Out:
# 0
# 2
# 4
# 6
# 8
# 10

# %%
# imprimir números pares
for i in range (0,11,2):
   print(i)
# Out:
# 0
# 2
# 4
# 6
# 8
# 10

# %%
# imprimir números impares
for i in range (1,11,2):
   print(i)
# Out:
# 1
# 3
# 5
# 7
# 9

# %%
# escrever um programa que o usuário digita um número de 1 a 10 e imprime a tabuada
resultado = int(input("escolha um número 1 a 10 "))
for i in range (0,10):
  if i / 2 == resultado:
    print (i)
# Out:
# escolha um número 1 a 10 9

# %%
# escrever um programa que o usuário digita um número de 1 a 10 e imprime a tabuada

numero = int (input ( "digite um número de 1 a 10 "))

for i in range (1,11):
  print (f"{numero} x {i} = {numero * i}")
# Out:
# digite um número de 1 a 10 7
# 7 x 1 = 7
# 7 x 2 = 14
# 7 x 3 = 21
# 7 x 4 = 28
# 7 x 5 = 35
# 7 x 6 = 42
# 7 x 7 = 49
# 7 x 8 = 56
# 7 x 9 = 63
# 7 x 10 = 70
