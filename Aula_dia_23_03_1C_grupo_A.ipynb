# %% [markdown]
# <a href="https://colab.research.google.com/github/mmanuss/PA-1C-grupo-A/blob/main/Aula_dia_23_03_1C_grupo_A.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a = int(input("digite um numero: "))
b = int(input("digie um numero: "))

if a > b:
  print(f"(a) maior que (b)>")

else:
    print(f"(b) maior que (a)")
# Out:
# digite um numero: 7
# digie um numero: 100
# (b) maior que (a)

# %%
#Escrever um programa que verifica se o úsuario é maior de idade

nome = str(input("digite seu nome: "))
idade = int(input("digite sua idade: "))

if idade > 18:
  print(f"{nome}, voce é maior de idade")

else:

     print (f"{idade}, voce é menor de idade")
# Out:
# digite seu nome: lua
# digite sua idade: 10
# 10, voce é menor de idade

# %%
numero = int(input("digite um número: "))

if numero % 2 == 0:
  print(f"o número {numero} é par.")
else:
  print(f"O número {numero} é impar")
# Out:
# digite um número: 10
# o número 10 é par.

# %%
senha = 1234

senha_digitada = int(input("digite sua senha: "))

if senha == senha_digitada

  print ("Acesso permitido")

else:
  print ("Senha incorreta, tente novamente")
# Out:
#   File "/tmp/ipykernel_6572/3938820475.py", line 5
#     if senha == senha_digitada
#                               ^
# SyntaxError: expected ':'

# %%
número = int (input("digte um numero "))
if numero > 10:
  print (f"(numero) maior que 10. ")

else:
  print (f"número é menor que 10. ")
# Out:
# digte um numero 8
# número é menor que 10.

# %%
compra = float(input("digite o valor da compra: "))
if compra > 100:
  desconto = compra * 0.9
  print (desconto)

else:
  print (compra)
# Out:
# digite o valor da compra 90
# 90.0

# %%
#escrever um programa que o aluno digite 04 notas dos bimestre

nota1 = float (input("digite a nota do primeiro bimestre "))
nota2 = float (input("digite a nota do segundo bimestre "))
nota3 = float (input(" digite a nota do terceiro bimestre "))
nota4 = float(input("digite a nota do quarto bimestre "))

media = (nota1 + nota2 + nota3 + nota4) / 4

if media >= 7:

  pint(f" voce foi aprovado, sua media foi: {media}")

elif media >= 5:

  print (f" voce ficou de recuperação, sua media foi : {media})")

else:

  print (f"voce foi reprovado, sua media foi: {media}")
# Out:
# digite a nota do primeiro bimestre 0
# digite a nota do segundo bimestre0
#  digite a nota do terceiro bimestre0
# digite a nota do quarto bimestre0
# voce foi reprovado, sua media foi: 0.0
