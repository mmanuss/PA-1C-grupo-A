# %% [markdown]
# <a href="https://colab.research.google.com/github/mmanuss/PA-1C-grupo-A/blob/main/aula_dia_30_03_1C_grupo_A.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Escrever um programa que faz as quatro operações aritimetica.


print("|-----------CALCULADORA SIMPLES-----------|")
print("|-----------------------------------------|")
print("|-------------------MENU------------------|")
print("|                                         |")
print("|Soma = 1                                 |")
print("|                                         |")
print("|Subtração = 2                            |")
print("|                                         |")
print("|Multiplicação = 3                        |")
print("|                                         |")
print("|Divisão = 4                              |")
print("|-----------------------------------------|")

a = int(input("digite um número "))
b = int(input("digite um número "))

operacao_escolhida = int(input("escolha a operação "))

resultado = 0

if operacao_escolhida == 1:
    resultado = a + b
    print(f"A soma de {a} mais {b} é igual a: {resultado}")
elif operacao_escolhida == 2:
    resultado = a - b
    print(f"A subtração de {a} menos {b} é igual a: {resultado}")
elif operacao_escolhida == 3:
    resultado = a * b
    print(f"A multiplicação de {a} por {b} é igual a: {resultado}")
elif operacao_escolhida == 4:
    if b != 0:
        resultado = a / b
        print(f"A divisão de {a} por {b} é igual a: {resultado}")
    else:
        print("Não é possível dividir por zero!")
else:
    print("Opção de operação inválida.")
# Out:
# |-----------CALCULADORA SIMPLES-----------|
# |-----------------------------------------|
# |-------------------MENU------------------|
# |                                         |
# |Soma = 1                                 |
# |                                         |
# |Subtração = 2                            |
# |                                         |
# |Multiplicação = 3                        |
# |                                         |
# |Divisão = 4                              |
# |-----------------------------------------|

# %%
#Escrever um programa que classifica os triângulos

# Verificar se forma um triângulo válido

# Tipo:

# Equilátero
# isósceles
# Escaleno

#entrada

lado1 = int (input("digite o lado do triângulo: "))
lado2 = int (input("digite o lado do triângulo: "))
lado3 = int (input("digite o lado do triângulo: "))

#processamento e saida

if lado1 + lado2 > lado3 and lado1 + lado3 > lado2 + lado3 > lado1
  print ("O triângulo é válido")
if lado1 == lado2 and lado2 == lado3:
  print ("triângulo equilátero")
  elif lado1 == lado2 or lado1 == lado3 or lado3 ==lado3
  print ("triângulo isósceles")
  else:
    print ("triângulo isósceles")

# %%
# Escrever um programa que classifica os triângulos

# Verificar se forma um triângulo válido

# Tipo:

# Equilátero
# Isósceles
# Escaleno

# entrada
lado1 = float(input("Digite o comprimento do primeiro lado do triângulo: "))
lado2 = float(input("Digite o comprimento do segundo lado do triângulo: "))
lado3 = float(input("Digite o comprimento do terceiro lado do triângulo: "))

# processamento e saída
# Condição de existência de um triângulo
if (lado1 + lado2 > lado3) and \n   (lado1 + lado3 > lado2) and \n   (lado2 + lado3 > lado1):
    print("Os lados fornecidos PODEM formar um triângulo.")

    # Classificação do tipo de triângulo
    if lado1 == lado2 and lado2 == lado3:
        print("É um triângulo EQUILÁTERO.")
    elif lado1 == lado2 or lado1 == lado3 or lado2 == lado3:
        print("É um triângulo ISÓSCELES.")
    else:
        print("É um triângulo ESCALENO.")
else:
    print("Os lados fornecidos NÃO PODEM formar um triângulo válido.")

# %%
# Escrever um programa que faz as quatro operações aritimetica.


print("|-----------CALCULADORA SIMPLES-----------|")
print("|-----------------------------------------|")
print("|-------------------MENU------------------|")
print("|                                         |")
print("|Soma = 1                                 |")
print("|                                         |")
print("|Subtração = 2                            |")
print("|                                         |")
print("|Multiplicação = 3                        |")
print("|                                         |")
print("|Divisão = 4                              |")
print("|-----------------------------------------|")

# entrada


num1 = float (input("digite um número "))
opcao = int (input("digite a opcao desejada"))
num2 = float (input("digite um número: ")


# processamento
